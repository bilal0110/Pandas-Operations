# %% [markdown]
# # Filtering and Sorting Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2. Import the dataset *chipotle.tsv*

# %%
pd.read_table('chipotle.tsv')
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo=pd.read_table('chipotle.tsv')
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?
#
# Use `str` attribute to remove the $ sign and convert the column to proper numeric type data before filtering.

# %%
chipo['item_price']=[i.strip('$') if type(i)==str else i for i in chipo['item_price']]

# %%
chipo['item_price']=chipo['item_price'].astype('float')

# %% [markdown]
# # Step 4.How many products cost more than $10.

# %%
df=chipo[chipo['item_price']>=10.00]
print('We Have',df['item_name'].nunique(),'products which costs more than 10$')
# Out:
# We Have 31 products which costs more than 10$

# %% [markdown]
# ### Step 5. What is the price of each item?
# print a data frame with only two columns `item_name` and `item_price`

# %%
chipo.groupby(['item_name'])['item_price'].sum().sort_values(ascending=False).reset_index()
# Out:
#                                 item_name  item_price
# 0                            Chicken Bowl     7342.73
# 1                         Chicken Burrito     5575.82
# 2                           Steak Burrito     3851.43
# 3                              Steak Bowl     2260.19
# 4                     Chips and Guacamole     2201.04
# 5                      Chicken Salad Bowl     1228.75
# 6                      Chicken Soft Tacos     1108.09
# 7                          Veggie Burrito      934.77
# 8                        Barbacoa Burrito      894.75
# 9                             Veggie Bowl      867.99
# 10                          Carnitas Bowl      736.71
# 11                          Barbacoa Bowl      672.36
# 12                       Carnitas Burrito      597.83
# 13                       Steak Soft Tacos      536.05
# 14                                  Chips      494.34
# 15                   Chicken Crispy Tacos      472.13
# ...

# %%
chipo[['item_name','item_price']]
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# ...                                     ...         ...
# 4617                          Steak Burrito       11.75
# 4618                          Steak Burrito       11.75
# 4619                     Chicken Salad Bowl       11.25
# 4620                     Chicken Salad Bowl        8.75
# 4621                     Chicken Salad Bowl        8.75
#
# [4622 rows x 2 columns]

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
chipo.sort_values(by='item_name')
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description  item_price
# 3389                                        [Diet Coke]       12.98
# 341                                         [Diet Coke]        6.49
# 1849                                             [Coke]        6.49
# 1860                                        [Diet Coke]        6.49
# 2713                                             [Coke]        6.49
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
chipo.groupby(['item_name'])['item_price'].max().reset_index()
# Out:
#                                 item_name  item_price
# 0                       6 Pack Soft Drink       12.98
# 1                           Barbacoa Bowl       11.75
# 2                        Barbacoa Burrito       11.75
# 3                   Barbacoa Crispy Tacos       18.50
# 4                     Barbacoa Salad Bowl       11.89
# 5                     Barbacoa Soft Tacos       11.75
# 6                           Bottled Water       15.00
# 7                                    Bowl       22.20
# 8                                 Burrito        7.40
# 9                             Canned Soda        4.36
# 10                      Canned Soft Drink        5.00
# 11                          Carnitas Bowl       35.25
# 12                       Carnitas Burrito       18.50
# 13                  Carnitas Crispy Tacos       17.98
# 14                         Carnitas Salad        8.99
# 15                    Carnitas Salad Bowl       11.89
# ...

# %%
chipo[chipo['item_price']>=44.25]
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %% [markdown]
# ### Step 8. How many times were a Veggie Salad Bowl ordered?

# %%
chipo['item_name'].value_counts().reset_index().loc[[33]]
# Out:
#                 index  item_name
# 33  Veggie Salad Bowl         18

# %% [markdown]
# ### Step 9. How many times people orderd Canned Soda?

# %%
chipo['item_name'].value_counts().reset_index().loc[[11]]
# Out:
#           index  item_name
# 11  Canned Soda        104
